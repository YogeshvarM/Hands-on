# %%
#Importing_Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Opening_CSV
df_happiness=pd.read_csv(r"C:\Users\varyo\Downloads\world-happiness-report-2021.csv")

# %%
#Viewing_Dataframe
df_happiness.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %% [markdown]
# "This dataset is about the indicator of happiness in all around the world by the following factors such as
# -GDP per Capita
# -Social Support
# -Healthy Life Expectancy
# -Freedom
# -Generosity
# -Corruption"

# %%
#Data cleaning

# %%
#Checking _for_nulls_count_in_Dataset
df_happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %% [markdown]
# After seeing the info of dataframe we can confirm that there is no null value in dataset.

# %%
#Removing_unnecessary_futures_for_analysis
df_happiness=df_happiness.drop(['Standard error of ladder score','upperwhisker','lowerwhisker','Explained by: Log GDP per capita','Explained by: Social support','Explained by: Healthy life expectancy','Explained by: Freedom to make life choices','Explained by: Generosity','Explained by: Perceptions of corruption','Dystopia + residual','Ladder score in Dystopia'],axis=1)

# %%
df_happiness.head()
# Out:
#   Country name Regional indicator  Ladder score  Logged GDP per capita  \
# 0      Finland     Western Europe         7.842                 10.775
# 1      Denmark     Western Europe         7.620                 10.933
# 2  Switzerland     Western Europe         7.571                 11.117
# 3      Iceland     Western Europe         7.554                 10.878
# 4  Netherlands     Western Europe         7.464                 10.932
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.954                     72.0                         0.949
# 1           0.954                     72.7                         0.946
# 2           0.942                     74.4                         0.919
# 3           0.983                     73.0                         0.955
# 4           0.942                     72.4                         0.913
#
#    Generosity  Perceptions of corruption
# 0      -0.098                      0.186
# ...

# %%
#Correlation_between_features

# %%
df_happiness.corr()
# Out:
#                               Ladder score  Logged GDP per capita  \
# Ladder score                      1.000000               0.789760
# Logged GDP per capita             0.789760               1.000000
# Social support                    0.756888               0.785299
# Healthy life expectancy           0.768099               0.859461
# Freedom to make life choices      0.607753               0.432323
# Generosity                       -0.017799              -0.199286
# Perceptions of corruption        -0.421140              -0.342337
#
#                               Social support  Healthy life expectancy  \
# Ladder score                        0.756888                 0.768099
# Logged GDP per capita               0.785299                 0.859461
# Social support                      1.000000                 0.723256
# Healthy life expectancy             0.723256                 1.000000
# Freedom to make life choices        0.482930                 0.461494
# ...

# %%
corelation_matrix=df_happiness.corr()
sns.heatmap(corelation_matrix,annot=True)
plt.title('Corelation between features')
plt.xlabel('Features determining Happiness')
plt.ylabel('Features determining Happiness')
plt.show()

# %% [markdown]
# #Weak_Correlation
# "Ladder score vs Perceptions of corruption" is considered to be Weak_correlation!
